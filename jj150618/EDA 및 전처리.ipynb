# %%
import pandas as pd

train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %% [markdown]
# ### data_description
# * MSSubClass : 건물 등급
# * MSZoning : 일반 구역 분류 (농업, 상업, 주거 등)
# * LotFrontage : 마당? 규모
# * LotArea : 주택 바닥 규모
# * Street : (자갈, 포장)
# * Alley : 골목 (자갈, 포장, X)
# * LotShape : 주택 모양 (규칙 - 불규칙)
# * LandContour : 평탄 정도
# * Utilities : (전기, 가스, 수도 등)
# * LotConfig : 주택 주변 (골목 등)
# * LandSlope : 경사
# * Neighborhood : Ames시 내의 물리적 위치
# * Condition1 : 주요 도로 또는 철도와의 근접성
# * Condition2 : 위와 동일 (둘 이상 있는 경우)
# * BldgType : 주거 유형 (단독 주택, 타운 하우스 등)
# * HouseStyle : 층 수?
# * OverallQual : 전체 재료 및 마감 품질
# * OverallCond : 전체 상태 등급
# * YearBuilt : 건설 연도
# * YearRemodAdd : 리모델링 연도
# * RoofStyle : 지붕 모양 (외쪽, 박공, 평 등)
# * RoofMatl : 지붕 재료
# * Exterior1st : 집 외부 커버
# * Exterior2nd : 위와 동일 (둘 이상 있는 경우)
# * MasVnrType : 벽돌 유형
# * MasVnrArea : 평당 벽돌 면적
# * ExterQual : 외장재 품질
# * ExterCond : 외장재 상태
# * Foundation : 기초 유형
# * BsmtQual : 지하 높이
# * BsmtCond : 지하실 상태
# * BsmtExposure : 정원 수준의 지하 벽
# * BsmtFinType1 : 지하실1 마감 품질
# * BsmtFinSF1 : 지하실1 면적 규모
# * BsmtFinType2 : 지하실2 마감 품질
# * BsmtFinSF2 : 지하실2 면적 규모
# * BsmtUnfSF : 미완성된 지하실 면적
# * TotlaBsmtSF : 지하 총 면적 규모
# * Heating : 난방 유형
# * HeatingQC : 난방 품질 및 상태
# * CentralAir : 중앙 에어컨
# * Electrical : 전기 시스템
# * 1stFlrSF : 1층 면적
# * 2ndFlrSF : 2층 면적
# * LowQualFinSF : 전층 저품질 마감 면적
# * GrLivArea : 지상 거실 면적
# * BsmtFullBath : 지하 전체 욕실
# * BsmtHalfBath : 지하 반 욕실
# * FullBath : 등급 이상 전체 욕실
# * HalfBath : 등급 이상 반 욕실
# * Bedroom : 지상 침실 수
# * Kitchen : 주방 수
# * KitchenQual : 주방 품질
# * TotRmsAbcGrd : 화장실 제외한 전체 방 수
# * Functional : 기능 등급
# * Fireplaces : 벽난로 수
# * FireplaceQu : 벽난로 품질
# * GarageType : 차고 위치
# * GarageYrBlt : 차고 건설 연도
# * GarageFinsh : 차고 마감
# * GarageCars : 수용가능한 차 대수
# * GarageArea : 차고 면적
# * GarageQual : 차고 품질
# * GarageCond : 차고 상태
# * PavedDrive : 포장 진입로
# * WoodDeckSF : 목재 데크 면적
# * OpenPorchSF : 열린 현관 영역
# * EnclosedPorch : 닫힌 현관 영역
# * 3SsnPorch : 3계절 현관 영역
# * ScreenPorch : 스크린 현관 영역
# * PoolArea : 수영장 면적
# * PoolQC : 수영장 품질
# * Fence : 울타리 품질
# * MiscFeature : 기타 (엘베, 테니스 코트 등)
# * MiscVal : 기타의 가치
# * MoSold : 판매 달
# * YrSold : 판매 연도
# * SaleType : 판매 유형
# * SaleCondition : 판매 조건

# %%
#descriptive statistics summary
train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# # 중요도 상위권 데이터 비교

# %%
import seaborn as sns

sns.distplot(train['SalePrice']);
# Out:
# C:\Users\gimhu\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
var = 'GrLivArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %%
var = 'TotalBsmtSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %%
import matplotlib.pyplot as plt

var = 'OverallQual'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'GarageCars'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
var = 'OverallCond'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %%
train['OverallCond']
# Out:
# 0       5
# 1       8
# 2       5
# 3       5
# 4       5
#        ..
# 1455    5
# 1456    6
# 1457    9
# 1458    6
# 1459    6
# Name: OverallCond, Length: 1460, dtype: int64

# %% [markdown]
# # 상관계수 확인
# ## 추후에 전처리 하면서 필요한 것들만 추가적으로 확인 필요

# %%
#correlation matrix
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# # 결측치 확인

# %%
#missing data
total = train.isnull().sum().sort_values(ascending=False)
percent = (train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(30)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Id                0  0.000000
# Functional        0  0.000000
# Fireplaces        0  0.000000
# KitchenQual       0  0.000000
# KitchenAbvGr      0  0.000000
# BedroomAbvGr      0  0.000000
# HalfBath          0  0.000000
# FullBath          0  0.000000
# BsmtHalfBath      0  0.000000
# TotRmsAbvGrd      0  0.000000
# GarageCars        0  0.000000

# %% [markdown]
# ### 결측치가 존재할 수 밖에 없는 데이터가 있을 것이고,
# ### 결측치가 없으면 안되는 데이터도 있을 것이다.
#
# PoolQC는 수영장 품질 -> 없는 집은 당연히 없을 것이고, 이것을 포함하여 학습하는게 중요한가?
# 수영장 면적 데이터를 확인해보고, 수영장의 존재 유무로 교체하는게 더 좋을 수도 있다.
# 아래 데이터를 확인해보면 대부분 0이다..
# 그냥 0인 경우 수영장이 없다. 그 외에는 수영장이 존재한다로 변경하는게 더 도움이 될 것이다.

# %%
sns.distplot(train['PoolArea']);
# Out:
# C:\Users\gimhu\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
train.loc[train['PoolArea']!=0,'PoolArea'] = 1
train.loc[train['PoolArea']==0,'PoolArea'] = 0
test.loc[test['PoolArea']!=0,'PoolArea'] = 1
test.loc[test['PoolArea']==0,'PoolArea'] = 0

# %% [markdown]
# MiscFeature는 기타로 존재하는 것들이다.
# 어떤 것들이 있는지 확인해보자
# shed의 경우 창고인데, 이 부분이 집값에 영향 주는 것이 수영장의 유무보다 없을 것 같다.
#
# Alley의 경우 grvl - 자갈 , pave - 포장길인데,
# 위의 경우와 동일하게 영향이 없을 것 같다.
# 그냥 삭제하자.

# %%
train['MiscFeature'].value_counts()
# Out:
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
train['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
train = train.drop(columns=['MiscFeature','Alley'])
test = test.drop(columns=['MiscFeature','Alley'])

# %% [markdown]
# # 스케일링
# 집값의 경우 왼쪽으로 치우져있다. 로그 스케일링을 이용해서 편향을 오른쪽으로 변경하자

# %%
train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
import numpy as np

plt.title('Log Transformed sale price histogram')
log_scaleprice=np.log1p(train['SalePrice'])
sns.distplot(log_scaleprice)

# 추후에 expm1()을 이용하여 복구해서 데이터 사용
# Out:
# C:\Users\gimhu\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Log Transformed sale price histogram'}, xlabel='SalePrice', ylabel='Density'>

# %%
train['SalePrice'] = np.log1p(train['SalePrice'])

# %%
from pycaret.regression import *
reg1 = setup(train, target = 'SalePrice', session_id = 1)
# Out:
# <style  type="text/css" >
# #T_69b99_row0_col1,#T_69b99_row3_col1,#T_69b99_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_69b99_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_69b99_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_69b99_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_69b99_row0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_69b99_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_69b99_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_69b99_row1_col1" class="data row1 col1" >SalePrice</td>
#             </tr>
# ...

# %%
top5 = compare_models(sort='MAE', n_select=5)
# Out:
# <style  type="text/css" >
#     #T_0997d_ th {
#           text-align: left;
# ...

# %%
catboost = create_model('catboost', verbose = False)
gbr = create_model('gbr', verbose = False)
lightgbm = create_model('lightgbm', verbose = False)
xgboost = create_model('xgboost', verbose = False)

# %%
plot_model(catboost, plot = 'feature')

# %%
interpret_model(catboost)

# %%
tuned_top5 = [tune_model(i) for i in top5]
# Out:
# <style  type="text/css" >
# #T_13123_row10_col0,#T_13123_row10_col1,#T_13123_row10_col2,#T_13123_row10_col3,#T_13123_row10_col4,#T_13123_row10_col5{
#             background:  yellow;
#         }</style><table id="T_13123_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13123_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_13123_row0_col0" class="data row0 col0" >0.0965</td>
#                         <td id="T_13123_row0_col1" class="data row0 col1" >0.0594</td>
# ...

# %%
blender_top5 = blend_models(estimator_list=tuned_top5)
# Out:
# <style  type="text/css" >
# #T_ba293_row10_col0,#T_ba293_row10_col1,#T_ba293_row10_col2,#T_ba293_row10_col3,#T_ba293_row10_col4,#T_ba293_row10_col5{
#             background:  yellow;
#         }</style><table id="T_ba293_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba293_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ba293_row0_col0" class="data row0 col0" >0.0804</td>
#                         <td id="T_ba293_row0_col1" class="data row0 col1" >0.0256</td>
# ...

# %%
final_model = finalize_model(blender_top5)
prediction = predict_model(final_model, data=test)

# %%
sub = pd.read_csv('../data/sample_submission.csv')
sub['SalePrice'] = np.expm1(prediction['Label'])
sub
# Out:
#         Id      SalePrice
# 0     1461  132390.056754
# 1     1462  165744.819516
# 2     1463  195760.305675
# 3     1464  203733.255318
# 4     1465  200821.375220
# ...    ...            ...
# 1454  2915   91702.317174
# 1455  2916   93937.802653
# 1456  2917  166045.577395
# 1457  2918  126250.782801
# 1458  2919  219273.229034
#
# [1459 rows x 2 columns]

# %%
sub.to_csv( '../submit/baseline.csv', index=False)
